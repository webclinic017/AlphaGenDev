# %%
import backtrader as bt
import os
from datetime import datetime
from datetime import timedelta
from datetime import date
import yfinance as yf
import pandas as pd
import numpy as np
from tqdm import tqdm
import pyfolio as pf
from AlphaGenStrategies import *
from matplotlib import pyplot as plt
import pickle
import time
PATH_TO_SEC_DATA=os.environ['PATH_TO_SEC_DATA']

# %%
sts = [{'nl': 200, 'ns':150, 'ts' : 'Eret_extended', 'cp' : True}, {'nl': 200, 'ns':150, 'ts' : 'Fret_extended', 'cp' : True}]

# %%
st = sts[1]
cp = 1 if st['cp']else 0
name_st = f"{st['ts']}-{st['nl']}-{st['ns']}-{cp}"

with open(f'{PATH_TO_SEC_DATA}/cerebros/returns_St{name_st}', "rb") as input_file:
    returns = pickle.load(input_file)

with open(f'{PATH_TO_SEC_DATA}/cerebros/benchmark_St{name_st}', "rb") as input_file:
    ben = pickle.load(input_file)

with open(f'{PATH_TO_SEC_DATA}/cerebros/positions_St{name_st}', "rb") as input_file:
    positions = pickle.load(input_file)

with open(f'{PATH_TO_SEC_DATA}/cerebros/transactions_St{name_st}', "rb") as input_file:
    transactions = pickle.load(input_file)

ben.name = 'Benchmark'
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, benchmark_rets =ben)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2014-12-31</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-12-20</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>83</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-0.878%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-5.963%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>10.282%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.03</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.04</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.27</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-21.438%</td>
#     </tr>
#     <tr>
# ...
